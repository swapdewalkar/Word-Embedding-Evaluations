# %%
Input is Vector Txt file

# %%
from scipy.spatial import distance
import operator
import numpy as np
from sklearn.cluster import KMeans
# vecs=[]
def getVector(file1):
    vocab=[]
    vecs=[]
#     P=np.array([np.empty(100)])
    data={}
    data1=open(file1).read().split("\n")
    for i in range(len(data1)):
        d1=data1[i].split(" ")
#         print(d1)
        word1=d1[0]
        vocab.append(word1)
#         print(word1)
        vec=d1[1:-1]
        if len(vec)==100:
            vecs.append(vec)
#             P=np.vstack((P,vec))
    P=np.vstack(vecs)
    return P,vocab

# %%
P,vocab=getVector('_H_training_tsigmoid_learn0.01_F199.txt')

# %%
P.shape
# Out:
# (9574, 100)

# %%
def calculate_purity(dataset,N):
    y_pred = KMeans(n_clusters=N,init='k-means++').fit_predict(P)
    f=open('word-benchmarks-master/word-categorization/monolingual/en/'+dataset+'.csv')
    data=f.read().split("\n")
    concept=set()
    cat=set()
    AP_cluster={}
    AP_cluster_found={}
    for r in data:
        a = r.split(",")
        if(len(a)>=3) and a[0]!='' and a[2]!='':
            concept.add(a[2])
            cat.add(a[1])
            if a[2] in vocab:
                if a[1] in AP_cluster_found:
                    AP_cluster_found[a[1]].append(a[2])
                else:
                    AP_cluster_found[a[1]]=[a[2]]
            if a[1] in AP_cluster:
                AP_cluster[a[1]].append(a[2])
            else:
                AP_cluster[a[1]]=[a[2]]
#     print(len(concept),len(cat))
#     vocab_found=[]
#     vocab_not_found=[]
#     for c in concept:
#         if c in vocab:
#             vocab_found.append(c)
#         else:
#             vocab_not_found.append(c)
#     for k in AP_cluster:
#         print(k,len(AP_cluster[k]))
#     for k in AP_cluster_found:
#         print(k,len(AP_cluster_found[k]))

    predicated_cluster={}
    for p in range(len(y_pred)):
#         print(p,vocab[p])
        if y_pred[p] not in predicated_cluster:
            predicated_cluster[y_pred[p]]=[vocab[p]]
        else:
            predicated_cluster[y_pred[p]].append(vocab[p])
#     for k in predicated_cluster:
#         print(k,len(predicated_cluster[k]))
    matrix={}
    for c in AP_cluster_found:
        matrix[c]=np.zeros(21) 
        for con in AP_cluster_found[c]:
            for k in predicated_cluster:
                if con in predicated_cluster[k]:
                    matrix[c][k]+=1
    s=0
    sm=0
    for c in matrix:
        sm+=matrix[c].sum()
        s+=max(matrix[c])

    print(dataset,s/sm)

# %%
calculate_purity('ap',21)
calculate_purity('essli-2008',6)
calculate_purity('battig',10)
# Out:
# ap 0.36551724137931035
# essli-2008 0.6444444444444445
# battig 0.3565640194489465

# %%
vocab
# Out:
# ['stood',
#  'television',
#  'integrated',
#  'tabletop',
#  'fong',
#  'plate',
#  'martin',
#  'instructions',
#  'deduct',
#  'disappointing',
#  'shadow',
#  'eraser',
#  'path',
#  'hds',
#  'drilling',
#  'nec',
#  'suggest',
#  'athlon',
#  'mk',
#  'nuc',
#  'leaving',
#  'retains',
#  'revert',
#  'recording',
#  'warn',
#  'nightmare',
#  'unfamiliar',
#  'replacing',
#  'samsung',
#  'math',
#  'weekends',
#  'february',
#  'manufacture',
#  'spin',
#  'exceed',
#  'slot',
#  'drink',
#  'tries',
#  'interstate',
#  'loved',
#  'umbrella',
#  'retracted',
#  'pushed',
#  'folds',
#  'students',
#  'lose',
#  'woods',
#  'approach',
#  'usd',
#  'visible',
#  'supplies',
#  'gorgeous',
#  'assumption',
#  'instruction',
#  'both',
#  'splitters',
#  'returns',
#  'esc',
#  'wise',
#  'mortar',
#  'io',
#  'ae',
#  'cleverly',
#  'static',
#  'maps',
#  'spare',
#  'staring',
#  'stabilization',
#  'countless',
#  'syncing',
#  'capsule',
#  'dealer',
#  'compound',
#  'strap',
#  'short',
#  'concise',
#  'transfering',
#  'after',
#  'waste',
#  'bends',
#  'gone',
#  'shares',
#  'oz',
#  'idiot',
#  'formerly',
#  'gopro',
#  'notifications',
#  'wizard',
#  'surroundings',
#  'framerate',
#  'involve',
#  'planes',
#  'can',
#  'bodies',
#  'roads',
#  'foresee',
#  'grandkids',
#  'fork',
#  'heated',
#  'sleeping',
#  'corel',
#  'doubts',
#  'translate',
#  'links',
#  'cups',
#  'mph',
#  'church',
#  'keeping',
#  'week',
#  'english',
#  'issues',
#  'stepped',
#  'appealing',
#  'downfall',
#  'suddenly',
#  'sold',
#  'lansing',
#  'los',
#  'kinks',
#  'anchor',
#  'full',
#  'shuttle',
#  'megabytes',
#  'reputation',
#  'autofocus',
#  'lets',
#  'reasons',
#  'geocaching',
#  'backyard',
#  'fifth',
#  'saturday',
#  'traffic',
#  'dolby',
#  'folding',
#  'coloring',
#  'fujifilm',
#  'palm',
#  'addressed',
#  'misses',
#  'unsure',
#  'trendnet',
#  'mast',
#  'owners',
#  'optic',
#  'sandisk',
#  'watched',
#  'complicated',
#  'uh',
#  'draw',
#  'hopefully',
#  'cleaning',
#  'wheel',
#  'standby',
#  'sensible',
#  'sli',
#  'amd',
#  'matte',
#  'manufacturer',
#  'thingy',
#  'slips',
#  'binoculars',
#  'purchaser',
#  'activates',
#  'studying',
#  'dull',
#  'rugged',
#  'configuring',
#  'images',
#  'made',
#  'container',
#  'finer',
#  'net',
#  'explanation',
#  'zippers',
#  'cm',
#  'ample',
#  'lights',
#  'tying',
#  'exhibit',
#  'unnecessary',
#  'street',
#  'heard',
#  'neutral',
#  'cause',
#  'dashboard',
#  'rest',
#  'reducing',
#  'drawn',
#  'bounced',
#  'easy',
#  'affects',
#  'interrupt',
#  'high',
#  'relying',
#  'chunk',
#  'traveled',
#  'quickest',
#  'hill',
#  'manages',
#  'evga',
#  'cost',
#  'boards',
#  'articulated',
#  'youre',
#  'applicable',
#  'overheated',
#  'fears',
#  'discovery',
#  'backgrounds',
#  'dogs',
#  'friction',
#  'wee',
#  'smartware',
#  'glaring',
#  'obstructions',
#  'conditioning',
#  'senn',
#  'hide',
#  'tests',
#  'flawlessly',
#  'honor',
#  'outages',
#  'ounce',
#  'acquiring',
#  'in',
#  'razr',
#  'amplified',
#  'origami',
#  'rendition',
#  'hurry',
#  'brightly',
#  'widget',
#  'convert',
#  'overwhelmed',
#  'back',
#  'illuminated',
#  'acquired',
#  'trees',
#  'styli',
#  'signs',
#  'millions',
#  'resize',
#  'butt',
#  'stuttering',
#  'finest',
#  'normally',
#  'reds',
#  'whom',
#  'toggle',
#  'offering',
#  'case',
#  'engineered',
#  'tones',
#  'every',
#  'although',
#  'stays',
#  'intact',
#  'about',
#  'flickers',
#  'rates',
#  'pos',
#  'lowest',
#  'wholeheartedly',
#  'dot',
#  'safety',
#  'synch',
#  'identical',
#  'inventory',
#  'batch',
#  'returned',
#  'alike',
#  'engineers',
#  'broadcast',
#  'illuminates',
#  'radeon',
#  'know',
#  'desire',
#  'bothering',
#  'outright',
#  'particularly',
#  'logging',
#  'talking',
#  'road',
#  'bookmark',
#  'skins',
#  'command',
#  'live',
#  'sharp',
#  'wasting',
#  'additions',
#  'environments',
#  'cooler',
#  'shotgun',
#  'subdued',
#  'values',
#  'keen',
#  'as',
#  'character',
#  'exist',
#  'evaluate',
#  'clarity',
#  'npr',
#  'gf',
#  'videos',
#  'opt',
#  'flickering',
#  'ins',
#  'apprehensive',
#  'meant',
#  'darker',
#  'properly',
#  'scans',
#  'lighter',
#  'hookups',
#  'foot',
#  'dpi',
#  'too',
#  'like',
#  'optics',
#  'precision',
#  'write',
#  'serviceable',
#  'dime',
#  'turning',
#  'image',
#  'occupied',
#  'mechanical',
#  'u',
#  'social',
#  'loudly',
#  'akg',
#  'season',
#  'pentium',
#  'thumbnail',
#  'why',
#  'shake',
#  'husband',
#  'misplace',
#  'throws',
#  'collar',
#  'classical',
#  'organize',
#  'canada',
#  'bracket',
#  'podcasts',
#  'gary',
#  'author',
#  'narrowed',
#  'facebook',
#  'dud',
#  'admirably',
#  'ports',
#  'wrist',
#  'item',
#  'crammed',
#  'rural',
#  'fuses',
#  'speeds',
#  'wider',
#  'magazines',
#  'craigslist',
#  'keystroke',
#  'chromebooks',
#  'alternate',
#  'accompany',
#  'steering',
#  'emails',
#  'judging',
#  'fully',
#  'losing',
#  'mixed',
#  'acceleration',
#  'examine',
#  'propping',
#  'pcs',
#  'stores',
#  'distorts',
#  'notices',
#  'refuse',
#  'whites',
#  'sdxc',
#  'powershot',
#  'rails',
#  'tho',
#  'purse',
#  'availability',
#  'highly',
#  'vanguard',
#  'sennheiser',
#  'lasts',
#  'tutorials',
#  'blood',
#  'nitpick',
#  'hobbyist',
#  'arguably',
#  'adapted',
#  'controlled',
#  'future',
#  'france',
#  'coiled',
#  'quits',
#  'text',
#  'yellow',
#  'torrent',
#  'enjoyment',
#  'stealing',
#  'sessions',
#  'tall',
#  'protocols',
#  'jot',
#  'attic',
#  'conform',
#  'jobs',
#  'lengths',
#  'mature',
#  'explorer',
#  'tasks',
#  'everyone',
#  'snapshot',
#  'directions',
#  'rumble',
#  'navigon',
#  'paperwhite',
#  'itrip',
#  'help',
#  'kidding',
#  'cheap',
#  'ticket',
#  'speedlight',
#  'furthest',
#  'cf',
#  'saving',
#  'chromatic',
#  'conscious',
#  'each',
#  'excessively',
#  'house',
#  'wall',
#  'spreadsheet',
#  'shopped',
#  'sharpie',
#  'truly',
#  'drone',
#  'audioengine',
#  'alfa',
#  'fade',
#  'microfiber',
#  'chirp',
#  'par',
#  'microsd',
#  'feeding',
#  'alienware',
#  'builds',
#  'built',
#  'dvi',
#  'coby',
#  'intend',
#  'photoshop',
#  'find',
#  'encased',
#  'projecting',
#  'packing',
#  'mounts',
#  'ultrathin',
#  'ton',
#  'wonders',
#  'clouds',
#  'transformer',
#  'neatly',
#  'tangles',
#  'impressive',
#  'freeware',
#  'uuml',
#  'beeps',
#  'nerd',
#  'imagination',
#  'transmits',
#  'forces',
#  'expecting',
#  'bonus',
#  'mostly',
#  'stretchy',
#  'horrendous',
#  'clueless',
#  'discovering',
#  'rotate',
#  'paid',
#  'disappeared',
#  'draws',
#  'trail',
#  'clears',
#  'rig',
#  'obscure',
#  'verbatim',
#  'receiver',
#  'exit',
#  'siri',
#  'never',
#  'utilitarian',
#  'puck',
#  'recommendations',
#  'configured',
#  'hype',
#  'notably',
#  'aperture',
#  'sink',
#  'unlike',
#  'applicator',
#  'june',
#  'defects',
#  'walkman',
#  'supplement',
#  'pass',
#  'shattered',
#  'travelers',
#  'commonly',
#  'versa',
#  'dings',
#  'rocket',
#  'followed',
#  'evaluation',
#  'shift',
#  'soldered',
#  'oct',
#  'hike',
#  'consideration',
#  'tester',
#  'weakness',
#  'maxx',
#  'diffusers',
#  'offs',
#  'plethora',
#  'may',
#  'hassle',
#  'gotten',
#  'total',
#  'pans',
#  'decode',
#  'conductor',
#  'brake',
#  'sabertooth',
#  'flatter',
#  'reproduced',
#  'reminds',
#  'wrapped',
#  'cluttered',
#  'exhausted',
#  'moderate',
#  'brought',
#  'asrock',
#  'neon',
#  'atleast',
#  'newtrent',
#  'fun',
#  'saying',
#  'obvious',
#  'pick',
#  'bath',
#  'integration',
#  'compartment',
#  'between',
#  'crummy',
#  'ignore',
#  'audiophile',
#  'configure',
#  'ch',
#  'weigh',
#  'date',
#  'here',
#  'recieve',
#  'renders',
#  'clam',
#  'elaborate',
#  'plasmas',
#  'such',
#  'bizarre',
#  'polks',
#  'guided',
#  'recliner',
#  'remotely',
#  'cop',
#  'attest',
#  'stitch',
#  'mp',
#  'upside',
#  'tradeoff',
#  'repeat',
#  'refurb',
#  'fancier',
#  'shut',
#  'flashy',
#  'junky',
#  'tote',
#  'jack',
#  'wraps',
#  'stressed',
#  'celeron',
#  'antennae',
#  'faceplate',
#  'oversight',
#  'meelectronics',
#  'rearrange',
#  'ditch',
#  'physics',
#  'describe',
#  'refuses',
#  'variety',
#  'unplugging',
#  'strongly',
#  'cbs',
#  'connectivity',
#  'film',
#  'lower',
#  'dsp',
#  'features',
#  'alright',
#  'rows',
#  'covers',
#  'getting',
#  'fine',
#  'realtek',
#  'affair',
#  'outage',
#  'pouch',
#  'dr',
#  'unless',
#  'midrange',
#  'needs',
#  'ceilings',
#  'clutter',
#  'photographs',
#  'compass',
#  'silicone',
#  'alone',
#  'drawstring',
#  'toward',
#  'hides',
#  'conservative',
#  'fiddled',
#  'widi',
#  'foil',
#  'listings',
#  'pure',
#  'succeeded',
#  'gamer',
#  'upconverting',
#  'roam',
#  'cake',
#  'afternoon',
#  'lamps',
#  'unbalanced',
#  'stepping',
#  'bare',
#  'apple',
#  'painting',
#  'immediately',
#  'luggage',
#  'stating',
#  'qid',
#  'economical',
#  'buzzing',
#  'elgato',
#  'reflective',
#  'logo',
#  'foam',
#  'eyesight',
#  'ups',
#  'exploring',
#  'ham',
#  'april',
#  'ultimate',
#  'keyboard',
#  'swimming',
#  'noticed',
#  'envelope',
#  'smartphones',
#  'peoples',
#  'cobra',
#  'etrex',
#  'brick',
#  'clicking',
#  'downloaded',
#  'fidelity',
#  'routinely',
#  'sigma',
#  'canceling',
#  'usb',
#  'unusable',
#  'background',
#  'kicking',
#  'docs',
#  'advantages',
#  'magellan',
#  'starts',
#  'lowered',
#  'surprised',
#  'pleasant',
#  'meets',
#  'suited',
#  'stutter',
#  'where',
#  'relax',
#  'aluminum',
#  'pbs',
#  'buzz',
#  'thickness',
#  'hers',
#  'moko',
#  'theres',
#  'imacs',
#  'mediabridge',
#  'say',
#  'knowing',
#  'shoved',
#  'row',
#  'avail',
#  'compensate',
#  'went',
#  'bright',
#  'oops',
#  'brackets',
#  'strongest',
#  'dj',
#  'seconds',
#  'cropping',
#  'adore',
#  'reliability',
#  'shockingly',
#  'conditioner',
#  'definitive',
#  'tickets',
#  'logos',
#  'station',
#  'soundlink',
#  'sc',
#  'glow',
#  'solved',
#  'resistance',
#  'male',
#  'delighted',
#  'lte',
#  'rise',
#  'rma',
#  'adjustability',
#  'sign',
#  'somewhat',
#  'airplane',
#  'featured',
#  'tape',
#  'breeze',
#  'caps',
#  'paranoid',
#  'suggested',
#  'package',
#  'opposite',
#  'swivels',
#  'align',
#  'grid',
#  'toy',
#  'pet',
#  'recovered',
#  'kernel',
#  'theoretically',
#  'vibrate',
#  'aforementioned',
#  'spins',
#  'brainwavz',
#  'presence',
#  'plugging',
#  'supervisor',
#  'listeners',
#  'plague',
#  'cpl',
#  'reading',
#  'hear',
#  'reminded',
#  'recommends',
#  'fortunately',
#  'polycarbonate',
#  'composite',
#  'couch',
#  'hifi',
#  'smash',
#  'imperfections',
#  'successful',
#  'minimize',
#  'stylish',
#  'invest',
#  'beautifully',
#  'secures',
#  'v',
#  'shoot',
#  'mesh',
#  'amazons',
#  'iems',
#  'nephew',
#  'determined',
#  'copied',
#  'workhorse',
#  'monster',
#  'whisper',
#  'linked',
#  'nylon',
#  'domain',
#  'bother',
#  'coil',
#  'slr',
#  'take',
#  'dive',
#  'convince',
#  'readily',
#  'nintendo',
#  'surprise',
#  'big',
#  'lackluster',
#  'nexstar',
#  'dhcp',
#  'loves',
#  'hbo',
#  'refreshing',
#  'oacute',
#  'order',
#  'westone',
#  'news',
#  'word',
#  'uncovered',
#  'swinging',
#  'introduce',
#  'mkii',
#  'rent',
#  'bank',
#  'snapping',
#  'increments',
#  'tougher',
#  'surrounded',
#  'irritated',
#  'crease',
#  'messenger',
#  'football',
#  'pictured',
#  'digitizer',
#  'monkey',
#  'shorting',
#  'forever',
#  'matches',
#  'enthusiast',
#  'lunch',
#  'charger',
#  'bucket',
#  'toyota',
#  'damage',
#  'batteries',
#  'scale',
#  'won',
#  'european',
#  'useable',
#  'vibrant',
#  'cents',
#  'snooze',
#  'francisco',
#  'funny',
#  'shutoff',
#  'washers',
#  'mods',
#  'turned',
#  'vi',
#  'gb',
#  'acknowledged',
#  'extends',
#  'infinitely',
#  'layout',
#  'drain',
#  'killing',
#  'bicycle',
#  'spotting',
#  'alleviate',
#  'packaging',
#  'layers',
#  'support',
#  'boomy',
#  'digress',
#  'muffled',
#  'respectively',
#  'putting',
#  'utterly',
#  'operated',
#  'earplugs',
#  'handled',
#  'skills',
#  'beginners',
#  'pocket',
#  'casecrown',
#  'neighbors',
#  'reset',
#  'asus',
#  'classes',
#  'specialty',
#  'was',
#  'circumstances',
#  'exaggerated',
#  'pc',
#  'optical',
#  'discussed',
#  'thinner',
#  'feb',
#  'duo',
#  'presentation',
#  'poe',
#  'consumes',
#  'addresses',
#  'conserve',
#  'year',
#  'fear',
#  'tonal',
#  'produce',
#  'iq',
#  'major',
#  'thumping',
#  'ordered',
#  'savvy',
#  'away',
#  'retracts',
#  'hardest',
#  'signature',
#  'worries',
#  'protruding',
#  'flaps',
#  'jvc',
#  'processing',
#  'anticipate',
#  'food',
#  'whopping',
#  'sewing',
#  'strength',
#  'stairs',
#  'detach',
#  'expert',
#  'nuvi',
#  'whatever',
#  'solution',
#  'randomly',
#  'rooting',
#  'rode',
#  'crucial',
#  'ironically',
#  'totally',
#  'fair',
#  'entries',
#  'chewed',
#  'disconnected',
#  'portion',
#  'snorkeling',
#  'perhaps',
#  'exciting',
#  'its',
#  'listed',
#  'lineup',
#  'crimp',
#  'stand',
#  'combination',
#  'particle',
#  'method',
#  'budge',
#  'accidentally',
#  'se',
#  'displaylink',
#  'backing',
#  'lightest',
#  'ss',
#  'reported',
#  'ipod',
#  'touched',
#  'umbrellas',
#  'standpoint',
#  'seem',
#  'anything',
#  'official',
#  'lots',
#  'everyday',
#  'wallpaper',
#  'sent',
#  'outlast',
#  'nomad',
#  'stare',
#  'atop',
#  'ez',
#  'speedtest',
#  'bounces',
#  'calendar',
#  'prong',
#  'mirrorless',
#  'warehouse',
#  'distinctive',
#  'postage',
#  'aid',
#  'quest',
#  'clock',
#  'statement',
#  'tubing',
#  'updater',
#  ...]
